# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
print(f"Hello {input("Name? ")}")
# Out:
# Hello A

# %%
#W2A3
a = int(input("a = "))
b = int(input("b = "))
print(f"Sum: {a + b}", f"Difference: {a - b}", f"Product: {a * b}", f"a//b: {a//b}", f"a%b: {a%b}", f"a/b: {'%.2f'%(a/b)}")
# Out:
# Sum: 5 Difference: -1 Product: 6 a//b: 0 a%b: 2 a/b: 0.67

# %%
#W2A4
scores = input("Scores: ")
print(f"Average: {'%.1f'%((float(scores.split(" ")[0]) + float(scores.split(" ")[1]) + float(scores.split(" ")[2]) + float(scores.split(" ")[3]) * 2 + float(scores.split(" ")[4]) * 2 + float(scores.split(" ")[5]) * 3) / 10)}")
# Out:
# Average: 4.2

# %%
#W2A5
userInput = input("a b? ")
print(float(userInput.split(" ")[0]) ** float(userInput.split(" ")[1]))
# Out:
# 243.0

# %%
#W2A6
character = input("Char: ")
print(chr(ord(character)))
print(character.upper())
# Out:
# a
# A

# %%
#W2A7
print(f"A = {((13 ** 2) * 3) + 5}")
print(f"B = {13**2*3+5}")
# Out:
# A = 512
# B = 512

# %%
#W2A8
print(f"Farenheit: {9 / 5 * int(input("Celcius: ")) + 32}")
# Out:
# Farenheit: 77.0

# %%
#W2A9
print(f"Final Price: {'%.2f'%(float(input("Original Price: ")) * 1.4 + 10)}")
# Out:
# Final Price: 1400010.00

# %%
#W2A10
friendNames = input("Friend Names: ").split(" ")
print(f"Hi {friendNames[2]}, {friendNames[1]}, and {friendNames[0]}")
# Out:
# Hi c, b, and a

# %%
#W2A11
print(f"Seconds: {float(input("Hours: ")) * 3600 + float(input("Minutes: ")) * 60}")
# Out:
# Seconds: 44430900.0

# %%
#W2A12
print(f"Number of stickers: {int(input("Cube size: ")) ** 2 * 6}")
# Out:
# Number of stickers: 150

# %%
#W2A13
a = int(input("a: "))
b = int(input("b: "))
print(f"Last digit of product: {str(a * b)[-1]}")
# Out:
# Last digit of product: 0

# %%
#W2A14
a = int(input("a: "))
b = int(input("b: "))
a, b = b, a
print(a, b)
# Out:
# 43 34

# %%
#W2A15
n = int(input("n: "))
print(f"nth star number: {6 * n * (n - 1) + 1}")
# Out:
# nth star number: 13

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("  *")
print(" ***")
print("*****")
# Out:
#   *
#  ***
# *****

# %%
#W2A18
print("###   # #      ###  ###")
print(" #    #   #     #    #")
print(" #    #    #    #    #")
print(" #    #   #     #    #")
print(" #    # #       #    #")
# Out:
# ###   # #      ###  ###
#  #    #   #     #    #
#  #    #    #    #    #
#  #    #   #     #    #
#  #    # #       #    #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
